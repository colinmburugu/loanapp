# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('data2.csv')
data.head()
# Out:
#    id  def  age  inc_brac4  inc_brac3  inc_brac2  inc_brac1  income_missing  \
# 0   1    0   22          0          0          0          0               1
# 1   2    1   26          0          0          0          1               0
# 2   3    0   29          0          0          0          0               1
# 3   4    1   46          0          0          0          0               1
# 4   5    0   47          0          0          0          1               0
#
#    kin_missing  credit_score_avg     ...           exp-inc  rec_exp_r  \
# 0            1             14.32     ...          0.000000   0.000000
# 1            0              0.00     ...       2340.285714   0.420188
# 2            1             16.06     ...          0.000000   0.000000
# 3            1              0.00     ...          0.000000   0.000000
# 4            0              0.00     ...          0.000000   0.000000
#
#     d_exp_r  inc_exp_r   t_exp_r   w_exp_r   s_exp_r   p_exp_r   a_exp_r  \
# ...

# %%
corr = data.corr()
corr
# Out:
#                                id       def       age  inc_brac4  inc_brac3  \
# id                       1.000000  0.055058  0.004176  -0.013944   0.004243
# def                      0.055058  1.000000 -0.000127  -0.035208  -0.070359
# age                      0.004176 -0.000127  1.000000   0.060405   0.037505
# inc_brac4               -0.013944 -0.035208  0.060405   1.000000  -0.018925
# inc_brac3                0.004243 -0.070359  0.037505  -0.018925   1.000000
# inc_brac2               -0.004287 -0.035648  0.036565  -0.035078  -0.043667
# inc_brac1               -0.007500 -0.048684 -0.002840  -0.044040  -0.054824
# income_missing           0.023343  0.108026 -0.048157  -0.198220  -0.246758
# kin_missing              0.023343  0.108026 -0.048157  -0.198220  -0.246758
# credit_score_avg        -0.021845 -0.042140  0.056972  -0.073345  -0.092331
# credit_score            -0.022249 -0.040074  0.053713  -0.073132  -0.091963
# ...

# %%
for i in list(corr.columns):
    for j in list(corr.columns):
        if corr.loc[i,j]>0.7 and corr.loc[i,j] != 1:
            print (i, ' ',j ,' ', corr.loc[i,j])
# Out:
# credit_score_avg   credit_score   0.9964796916022949
# credit_score   credit_score_avg   0.9964796916022949
# deposit_max_avg   total_deposit   0.8396381210277769
# deposit_max_avg   monthly_deposit_avg   0.839638121019497
# deposit_max_avg   avg_max_sent   0.759871630367036
# total_deposit   deposit_max_avg   0.8396381210277769
# total_deposit   monthly_deposit_avg   1.0000000000000515
# total_deposit   avg_monthly_inc   0.7484223964358411
# total_deposit   monthly_exp_avg   0.7374848122460631
# monthly_deposit_avg   deposit_max_avg   0.839638121019497
# monthly_deposit_avg   total_deposit   1.0000000000000515
# monthly_deposit_avg   avg_monthly_inc   0.7484223964477821
# monthly_deposit_avg   monthly_exp_avg   0.7374848122583811
# max_rec_avg   total_rec   0.8022143093927165
# max_rec_avg   monthly_rec_avg   0.8022143094072861
# max_rec_avg   avg_monthly_inc   0.8032127974639066
# max_rec_avg   avg_max_sent   0.8790335478844861
# max_rec_avg   avg_monthly_sent   0.7448816125850131
# ...

# %%
from sklearn.model_selection import train_test_split
X = data.drop(columns=['id','def'])
y = data['def']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.35,random_state=0)

# %%
from sklearn.preprocessing import Imputer
imr = Imputer(missing_values='NaN',strategy= 'mean')
X_train_imr = imr.fit_transform(X_train)
X_test_imr = imr.transform(X_train)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train_imr,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance',ascending=False)
feature_importances
# Out:
#                          importance
# age                        0.164258
# credit_score               0.095773
# credit_score_avg           0.095353
# min_rec_avg                0.023179
# max_rec_avg                0.022051
# avg_min_sent               0.021634
# inc_exp_r                  0.020987
# airtime_min_avg            0.020791
# avg_monthly_inc            0.019905
# monthly_exp_avg            0.019697
# avg_withdrawls             0.016701
# avg_min_withdrawals        0.016569
# total_rec                  0.015756
# a_exp_r                    0.015650
# d_exp_r                    0.015370
# rec_inc_r                  0.015239
# exp-inc                    0.015066
# monthly_airtime_avg        0.015013
# rec_exp_r                  0.013467
# total_airtime              0.013364
# total_sent                 0.013337
# a_inc_r                    0.013298
# d_inc_r                    0.013201
# inc-exp                    0.012816
# avg_max_sent               0.012688
# ...
